# %% [raw]
# ---
# title: "About"
# execute:
#     enabled: true
# ---

# %% [markdown]
# About this site
#
# <h1>Good Good</h1>
# <h2>Bad Bad</h2>
# <h3>Better Better</h3>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=[1, 2, 3, 4]
y=[1, 4, 9, 16]
plt.plot(x,y)
plt.show()
